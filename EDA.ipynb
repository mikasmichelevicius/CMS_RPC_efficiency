# %%
import pandas as pd
import numpy as np

# %%
test_run = pd.read_csv('data.csv')

# %%
test_run.describe()
print(test_run['chamber'].nunique())
# Out:
# 480

# %%
print(test_run.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   chamber             1920 non-null   object
#  1   wheel               1920 non-null   int64
#  2   sector              1920 non-null   int64
#  3   station             1920 non-null   int64
#  4   avg_cluster_size    1920 non-null   float64
#  5   occupancy           1920 non-null   int64
#  6   avg_bx_dist         1920 non-null   float64
#  7   avg_no_of_clusters  1920 non-null   float64
#  8   avg_multiplicity    1920 non-null   float64
#  9   lumisections        1920 non-null   int64
#  10  type                1920 non-null   object
#  11  avg_efficiency      1920 non-null   float64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 180.1+ KB
# None

# %%
test_run.head(100)
# Out:
#            chamber  wheel  sector  station  avg_cluster_size  occupancy  \
# 0    W-2_RB1in_S01     -2       1        1           1.89560       9260
# 1   W-2_RB1out_S01     -2       1        1           1.86138       8352
# 2    W-2_RB2in_S01     -2       1        2           1.98668       9991
# 3   W-2_RB2out_S01     -2       1        2           1.81836       8419
# 4     W-2_RB3+_S01     -2       1        3           1.86244       4021
# ..             ...    ...     ...      ...               ...        ...
# 95    W-2_RB4-_S12     -2      12        4           1.60847       2469
# 96   W-1_RB1in_S01     -1       1        1           2.06804      15866
# 97  W-1_RB1out_S01     -1       1        1           2.06215      14134
# 98   W-1_RB2in_S01     -1       1        2           1.88589      12775
# 99  W-1_RB2out_S01     -1       1        2           1.96977      11665
#
#     avg_bx_dist  avg_no_of_clusters  avg_multiplicity  lumisections type  \
# ...
