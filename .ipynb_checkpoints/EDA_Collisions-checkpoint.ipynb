# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
col_dirs = os.listdir('Collisions/')
print(col_dirs)

list_of_df = []
for col_run in col_dirs:
    list_of_df.append(pd.read_csv('Collisions/'+col_run+'/'+col_run+'_final.csv'))
    
collision_data = pd.concat(list_of_df)
# Out:
# ['321887', '322068', '323727', '321880', '323524', '324998', '325022', '321820', '324764', '321818', '322252', '323525', '324997', '323980', '324791', '322492', '324765', '323775', '322201', '321817', '322179', '324245', '324077', '321730', '321755', '323495', '321909', '323696', '325159', '324078', '321990', '322381', '322113', '321908', '324022', '322319', '323493', '324835', '322332', '325117', '321778', '322599', '323474', '323487', '323473', '325172', '323488', '324202', '324205', '321777', '322106', '321712', '322356', '324293', '323841', '321832', '325001', '324785', '324315', '324747', '322625', '325099', '324970', '321834', '322222', '322480', '321833', '325000', '322088', '323702', '324769', '321475', '322204', '322605', '322430', '321879', '323940', '322633', '321813', '323778', '323526', '322407', '322431', '323725', '323983', '322118', '321760', '321794', '325101', '322324', '321758', '321961', '322348', '324841', '324846', '323693', '325100', '321933', '322322', '324021
# ...

# %%
df = collision_data
df['occupancy/LS'] = df['occupancy'] / df['lumisections']
df = df.reset_index(drop=True)
df.describe()
# Out:
#                  run         wheel        sector       station  \
# count   63360.000000  63360.000000  63360.000000  63360.000000
# mean   323224.863636      0.000000      6.375000      2.500000
# std      1218.646049      1.414225      3.428614      1.118043
# min    321475.000000     -2.000000      1.000000      1.000000
# 25%    321989.500000     -1.000000      3.750000      1.750000
# 50%    323480.500000      0.000000      6.000000      2.500000
# 75%    324239.000000      1.000000      9.000000      3.250000
# max    325172.000000      2.000000     12.000000      4.000000
#
#        avg_cluster_size      occupancy   avg_bx_dist  avg_no_of_clusters  \
# count      63360.000000   63360.000000  63360.000000        63360.000000
# mean           1.768594   26026.126878      0.013440            0.923000
# std            0.589515   28945.283787      0.062427            0.271374
# min            0.000000       0.000000     -1.150170            0.000000
# ...

# %% [markdown]
# # All Runs together

# %% [markdown]
# ### 1D histograms

# %%
df_hist = df
df_hist = df_hist.drop(['run', 'chamber', 'wheel', 'sector', 'station', 'type'], axis=1)
df_hist.hist(figsize=(16, 16), bins=100, xlabelsize=8, ylabelsize=8)
plt.show()

# %% [markdown]
# Droping records which: <br>
# 1- All atributes and fiducial efficiency equal to zero. <br>
# 2- Fiducial efficiency equal to zero with nonzero atributes. <br>
# 3- All atributes equal to zero with nonzero fiducial efficiency <br>

# %%
print('total records:',df.shape[0])
print('1-', df[ (df['occupancy'] == 0) & (df['fid_eff_ch_level'] == 0)].shape[0])
print('2-', df[ (df['occupancy'] != 0) & (df['fid_eff_ch_level'] == 0)].shape[0])
print('3-', df[ (df['occupancy'] == 0) & (df['fid_eff_ch_level'] != 0)].shape[0])
# Out:
# total records: 63360
# 1- 5040
# 2- 282
# 3- 1

# %%
i = df[df['fid_eff_ch_level'] == 0].index
df = df.drop(i)
i = df[(df['occupancy'] == 0) & (df['fid_eff_ch_level'] != 0)].index
df = df.drop(i)
df.shape[0]
# Out:
# 58037

# %%
df_hist = df
df_hist = df_hist.drop(['run', 'chamber', 'wheel', 'sector', 'station', 'type'], axis=1)
df_hist.hist(figsize=(16, 16), bins=100, xlabelsize=8, ylabelsize=8)
plt.show()

# %% [markdown]
# Looking at min and max values of Lumisections for samples with 'occupancy/LS'>=300, we can conclude that high number of 'occupancy/LS' are presence in it's histogram as a result of low Lumisections. after droping records with lumisections < 38 we reach to the following histogram for 'occupancy/LS'.

# %%
df[ (df['occupancy/LS'] >= 300) ].describe()
# Out:
#                  run       wheel      sector     station  avg_cluster_size  \
# count     866.000000  866.000000  866.000000  866.000000        866.000000
# mean   323623.658199    0.047344    6.450346    2.385681          1.922576
# std       133.559689    1.419541    3.447101    1.098176          0.211887
# min    323488.000000   -2.000000    1.000000    1.000000          1.309630
# 25%    323488.000000   -1.000000    3.000000    1.000000          1.784212
# 50%    323755.000000    0.000000    6.000000    2.000000          1.916345
# 75%    323755.000000    1.000000   10.000000    3.000000          2.049523
# max    323755.000000    2.000000   12.000000    4.000000          2.881440
#
#            occupancy  avg_bx_dist  avg_no_of_clusters  avg_multiplicity  \
# count     866.000000   866.000000          866.000000        866.000000
# mean    42137.583141     0.010443            1.002811          1.928162
# std     24583.010643     0.022958            0.001681          0.214174
# ...

# %%
df_droping_low_lumisections = df[df['lumisections'] > 40]

print('number of total samples:', df.shape[0])
print('number of samples with lumisections>38 :', df_droping_low_lumisections.shape[0])
print('maximum occupancy/LS value after droping low lumisections samples:', np.max(df_droping_low_lumisections['occupancy/LS']))
print('minimum lumisections value:',np.min(df_droping_low_lumisections['lumisections']))
plt.hist(np.array(df_droping_low_lumisections['occupancy/LS']) , bins=100)
plt.title('occupancy/LS')
plt.show()
# Out:
# number of total samples: 58037
# number of samples with lumisections>38 : 57164
# maximum occupancy/LS value after droping low lumisections samples: 228.16915422885572
# minimum lumisections value: 115

# %% [markdown]
# ### Correlations

# %%
df_cor = df_hist.drop(['avg_efficiency'], axis=1)
plt.figure(figsize=(8, 6))
cor = abs(df_cor.corr())
sns.heatmap(cor.round(decimals=2), 
            cmap='viridis', vmax=1.0, vmin=0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True)

# %% [markdown]
# ### 2D histograms

# %%
df_sns = df_hist.drop(['lumisections', 'avg_efficiency'], axis=1)
sns.pairplot(df_sns)

# %% [markdown]
# ### colorbar 2D histograms

# %% [markdown]
# The following histogram indicates that samples with lumisections <= 38 are in a seperate region from others

# %%
cm = plt.cm.get_cmap('viridis')
name2 = 'occupancy/LS'
name1 = 'avg_cluster_size'
x = np.array(df[name1])
y = np.array(df[name2])
z = np.array(df['lumisections'])
sc = plt.scatter(x, y, c=z, vmin=0, vmax=100, s=0.5, cmap=cm)
cbar = plt.colorbar(sc)
cbar.set_label('lumisections')
plt.xlabel(name1)
plt.ylabel(name2)
# Out:
# Text(0, 0.5, 'occupancy/LS')

# %% [markdown]
# Searching for efficiency regions:

# %%
cm = plt.cm.get_cmap('viridis')
name2 = 'occupancy/LS'
name1 = 'avg_cluster_size'
x = np.array(df[name1])
y = np.array(df[name2])
z = np.array(df['fid_eff_ch_level'])
sc = plt.scatter(x, y, c=z, vmin=0, vmax=100, s=0.5, cmap=cm)
cbar = plt.colorbar(sc)
cbar.set_label('fid_eff_ch_level')
plt.xlabel(name1)
plt.ylabel(name2)
# Out:
# Text(0, 0.5, 'occupancy/LS')

# %%
cm = plt.cm.get_cmap('viridis')
name2 = 'occupancy/LS'
name1 = 'avg_cluster_size'
x = np.array(df_droping_low_lumisections[name1])
y = np.array(df_droping_low_lumisections[name2])
z = np.array(df_droping_low_lumisections['fid_eff_ch_level'])
sc = plt.scatter(x, y, c=z, vmin=0, vmax=100, s=0.1, cmap=cm)
cbar = plt.colorbar(sc)
cbar.set_label('fid_eff_ch_level')
plt.xlabel(name1)
plt.ylabel(name2)
# Out:
# Text(0, 0.5, 'occupancy/LS')

# %%
cm = plt.cm.get_cmap('viridis')
# cm = plt.cm.get_cmap('viridis')
name2 = 'avg_no_of_clusters'
name1 = 'occupancy/LS'
x = np.array(df_droping_low_lumisections[name1])
y = np.array(df_droping_low_lumisections[name2])
z = np.array(df_droping_low_lumisections['fid_eff_ch_level'])
sc = plt.scatter(x, y, c=z, vmin=0, vmax=100, s=0.5, cmap=cm)
plt.colorbar(sc)
cbar.set_label('fid_eff_ch_level')
plt.xlabel(name1)
plt.ylabel(name2)
# Out:
# Text(0, 0.5, 'avg_no_of_clusters')

# %% [markdown]
# ## spatial features of Data
