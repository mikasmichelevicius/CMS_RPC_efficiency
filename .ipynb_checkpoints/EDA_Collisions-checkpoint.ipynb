# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
col_dirs = os.listdir('Collisions/')
print(col_dirs)

list_of_df = []
for col_run in col_dirs:
    list_of_df.append(pd.read_csv('Collisions/'+col_run+'/'+col_run+'_final.csv'))
    
df = pd.concat(list_of_df)
# Out:
# ['322179', '324293', '324970', '321475', '321305', '324878', '324980', '320917', '322022', '321457']

# %%
df['occupancy/LS'] = df['occupancy'] / df['lumisections']
df = df.reset_index(drop=True)
df.describe()
# Out:
#                  run        wheel       sector     station  avg_cluster_size  \
# count    4800.000000  4800.000000  4800.000000  4800.00000       4800.000000
# mean   322847.600000     0.000000     6.375000     2.50000          1.673960
# std      1622.410928     1.414361     3.428944     1.11815          0.787791
# min    320917.000000    -2.000000     1.000000     1.00000          0.000000
# 25%    321457.000000    -1.000000     3.750000     1.75000          1.528345
# 50%    322100.500000     0.000000     6.000000     2.50000          1.779250
# 75%    324878.000000     1.000000     9.000000     3.25000          1.976788
# max    324980.000000     2.000000    12.000000     4.00000         41.000000
#
#            occupancy  avg_bx_dist  avg_no_of_clusters  avg_multiplicity  \
# count    4800.000000  4800.000000         4800.000000       4800.000000
# mean    68427.510000     0.014411            0.924995          1.678632
# std     44223.414585     0.032876            0.268139          0.789199
# min         0.000000    -0.076679            0.000000          0.000000
# 25%     35231.750000     0.004199            1.001030          1.532345
# 50%     55400.500000     0.006051            1.002130          1.783255
# 75%     99431.000000     0.009547            1.003900          1.983387
# max    219511.000000     1.000000            1.006760         41.000000
#
#        lumisections  avg_efficiency  fid_eff_ch_level  occupancy/LS
# count   4800.000000     4800.000000       4800.000000   4800.000000
# mean    2082.400000       72.496590         84.535001     33.170298
# std      277.115208       25.873550         26.613226     21.518268
# min     1788.000000        0.000000          0.000000      0.000000
# 25%     1813.000000       61.367342         86.791766     17.041752
# 50%     2008.000000       82.559149         95.156996     26.952179
# 75%     2325.000000       89.392509         97.492885     48.459936
# max     2649.000000       96.429314        100.000000    110.364094

# %% [markdown]
# # All Runs together

# %%
df_hist = df
df_hist = df_hist.drop(['run', 'chamber', 'wheel', 'sector', 'station', 'type'], axis=1)
df_hist.hist(figsize=(16, 20), bins=100, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdeb800a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b21bb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b25b0f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b289630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b2bbbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b2fa1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b328780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b359d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b359da0>]],
#       dtype=object)

# %% [markdown]
# Dropping rows

# %%
df[df['avg_multiplicity'] >= 4]
# Out:
#          run         chamber  wheel  sector  station  avg_cluster_size  \
# 2549  324878  W-1_RB2out_S07     -1       7        2              41.0
#
#       occupancy  avg_bx_dist  avg_no_of_clusters  avg_multiplicity  \
# 2549         41          1.0                 1.0              41.0
#
#       lumisections type  avg_efficiency  fid_eff_ch_level  occupancy/LS
# 2549          1800  Col             0.0               0.0      0.022778

# %%
df[ (df['occupancy'] == 0) & (df['fid_eff_ch_level'] == 0)].shape[0]
# Out:
# 372

# %%
i = df[df['avg_multiplicity'] >= 4].index
df = df.drop(i)
df.shape[0]
# Out:
# 4799

# %%
i = df[df['occupancy'] == 0].index
df = df.drop(i)
df.shape[0]
# Out:
# 4427

# %%
df_hist = df
df_hist = df_hist.drop(['run', 'chamber', 'wheel', 'sector', 'station', 'type'], axis=1)
df_hist.hist(figsize=(16, 20), bins=100, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1c4d79e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1b9ceac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf28a27748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1c54f860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1be3ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1be5d400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1be889b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1bebbf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf1bebbfd0>]],
#       dtype=object)

# %%
df_hist.describe()
# Out:
#        avg_cluster_size      occupancy  avg_bx_dist  avg_no_of_clusters  \
# count       4427.000000    4427.000000  4427.000000         4427.000000
# mean           1.805740   74192.908742     0.015399            1.002705
# std            0.265724   41142.188429     0.030561            0.001630
# min            1.226550   12800.000000    -0.076679            1.000080
# 25%            1.591520   38596.500000     0.004620            1.001140
# 50%            1.807200   62789.000000     0.006358            1.002730
# 75%            1.996615  103170.000000     0.010153            1.003970
# max            3.349460  219511.000000     0.427211            1.006760
#
#        avg_multiplicity  lumisections  avg_efficiency  fid_eff_ch_level  \
# count       4427.000000   4427.000000     4427.000000       4427.000000
# mean           1.810805   2082.256155       78.604841         91.657557
# std            0.267732    277.135186       15.671979         10.722359
# min            1.227240   1788.000000        0.000000          0.000000
# 25%            1.596785   1813.000000       73.437463         89.131096
# 50%            1.811110   1925.000000       83.839153         95.911785
# 75%            2.003590   2325.000000       90.060507         97.575716
# max            3.352250   2649.000000       96.429314        100.000000
#
#        occupancy/LS
# count   4427.000000
# mean      35.965080
# std       20.037989
# min        6.050208
# 25%       18.677902
# 50%       30.536806
# 75%       50.316313
# max      110.364094

# %%
df_hist = df_hist.drop(['lumisections'], axis=1)
sns.pairplot(df_hist)

# %% [markdown]
# creating classes A and B spliting by fid_eff_ch_level

# %%
print(len(df_hist))
print(df_hist[df_hist['fid_eff_ch_level'] >= 96].shape[0])
# Out:
# 4427
# 2189

# %%
c = []
df_hist = df_hist.reset_index(drop=True)
for i in range(len(df_hist)):
    if df_hist['fid_eff_ch_level'][i] >= 96:
        c.append('A')
    else:
        c.append('B')
df_hist = df_hist.assign( cl = c)
df_hist.head()
# Out:
#    avg_cluster_size  occupancy  avg_bx_dist  avg_no_of_clusters  \
# 0           1.88807      87935     0.007343             1.00403
# 1           1.84406      78345     0.008426             1.00371
# 2           2.00793      93656     0.007247             1.00405
# 3           1.86217      80453     0.013540             1.00344
# 4           1.84129      37288     0.004345             1.00104
#
#    avg_multiplicity  avg_efficiency  fid_eff_ch_level  occupancy/LS cl
# 0           1.89568       52.477024         96.665222     49.180649  A
# 1           1.85090       57.869761         97.633621     43.817114  A
# 2           2.01606       79.958797         98.162010     52.380313  A
# 3           1.86857       83.298027         98.551542     44.996085  A
# 4           1.84320       91.871521         98.427452     20.854586  A

# %%
sns.pairplot(df_hist, hue="cl")
